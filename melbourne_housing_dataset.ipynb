# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading the Data

# %%
df = pd.read_csv('melbourne_housing_FULL.csv')

# %% [markdown]
# Number of rows and coulmn

# %%
df.shape
# Out:
# (34857, 21)

# %% [markdown]
# viewing first few samples

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 0  3/09/2016       2.5    3067.0      ...            1.0  1.0     126.0
# 1  3/12/2016       2.5    3067.0      ...            1.0  1.0     202.0
# 2  4/02/2016       2.5    3067.0      ...            1.0  0.0     156.0
# 3  4/02/2016       2.5    3067.0      ...            2.0  1.0       0.0
# 4  4/03/2017       2.5    3067.0      ...            2.0  0.0     134.0
#
#    BuildingArea  YearBuilt         CouncilArea Lattitude  Longtitude  \
# ...

# %% [markdown]
# Statistical Information

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %% [markdown]
# count gives information on missing values

# %% [markdown]
# Gives information about total number of columns and number of samples and data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
# Suburb           34857 non-null object
# Address          34857 non-null object
# Rooms            34857 non-null int64
# Type             34857 non-null object
# Price            27247 non-null float64
# Method           34857 non-null object
# SellerG          34857 non-null object
# Date             34857 non-null object
# Distance         34856 non-null float64
# Postcode         34856 non-null float64
# Bedroom2         26640 non-null float64
# Bathroom         26631 non-null float64
# Car              26129 non-null float64
# Landsize         23047 non-null float64
# BuildingArea     13742 non-null float64
# YearBuilt        15551 non-null float64
# CouncilArea      34854 non-null object
# Lattitude        26881 non-null float64
# Longtitude       26881 non-null float64
# Regionname       34854 non-null object
# Propertycount    34854 non-null float64
# ...

# %% [markdown]
# Categorical Variables

# %% [markdown]
# Based on the above information the variables 'Suburb', 'Address', 'Type', 'Method', 'SellerG', 'CouncilArea','Regionname'

# %% [markdown]
# Identify object column

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['Suburb', 'Address', 'Type', 'Method', 'SellerG', 'Date', 'CouncilArea',
#        'Regionname'],
#       dtype='object')

# %% [markdown]
# Removing or imputing missing values

# %%
pd.isnull(df).sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8887 entries, 2 to 34856
# Data columns (total 21 columns):
# Suburb           8887 non-null object
# Address          8887 non-null object
# Rooms            8887 non-null int64
# Type             8887 non-null object
# Price            8887 non-null float64
# Method           8887 non-null object
# SellerG          8887 non-null object
# Date             8887 non-null object
# Distance         8887 non-null float64
# Postcode         8887 non-null float64
# Bedroom2         8887 non-null float64
# Bathroom         8887 non-null float64
# Car              8887 non-null float64
# Landsize         8887 non-null float64
# BuildingArea     8887 non-null float64
# YearBuilt        8887 non-null float64
# CouncilArea      8887 non-null object
# Lattitude        8887 non-null float64
# Longtitude       8887 non-null float64
# Regionname       8887 non-null object
# Propertycount    8887 non-null float64
# ...

# %%
pd.isnull(df).sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
import seaborn as sns
# %matplotlib inline

# %%
df.corr()
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.475074  0.276585  0.084236  0.964465  0.624070
# Price          0.475074  1.000000 -0.231212  0.046033  0.460880  0.463501
# Distance       0.276585 -0.231212  1.000000  0.489537  0.283460  0.122132
# Postcode       0.084236  0.046033  0.489537  1.000000  0.087286  0.111617
# Bedroom2       0.964465  0.460880  0.283460  0.087286  1.000000  0.626493
# Bathroom       0.624070  0.463501  0.122132  0.111617  0.626493  1.000000
# Car            0.401423  0.209464  0.259374  0.055531  0.405570  0.310962
# Landsize       0.101158  0.058375  0.138559  0.069623  0.101035  0.075939
# BuildingArea   0.606738  0.507284  0.135509  0.077091  0.595299  0.553855
# YearBuilt      0.006935 -0.313664  0.313383  0.089913  0.016310  0.192914
# Lattitude      0.018758 -0.224255 -0.055317 -0.195081  0.022745 -0.041859
# Longtitude     0.083016  0.212174  0.163941  0.358005  0.082671  0.109268
# ...

# %%
sns.heatmap(df.corr(), annot= True, cbar= False,linewidth=.1)

# %% [markdown]
# Rooms and Bedroom2 are highly correlated, so removing Bedroom2 predictor variable

# %%
df = df.drop('Bedroom2', axis = 1)

# %%
df
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 2             Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 4             Abbotsford         5 Charles St      3    h  1465000.0     SP
# 6             Abbotsford          55a Park St      4    h  1600000.0     VB
# 11            Abbotsford         124 Yarra St      3    h  1876000.0      S
# 14            Abbotsford        98 Charles St      2    h  1636000.0      S
# 18            Abbotsford        10 Valiant St      2    h  1097000.0      S
# 24            Abbotsford      40 Nicholson St      3    h  1350000.0     VB
# 25            Abbotsford  123/56 Nicholson St      2    u   750000.0      S
# 30            Abbotsford        16 William St      2    h  1310000.0      S
# 32            Abbotsford          42 Henry St      3    h  1200000.0      S
# 35            Abbotsford          78 Yarra St      3    h  1176500.0      S
# ...

# %%
df.corr()
# Out:
#                   Rooms     Price  Distance  Postcode  Bathroom       Car  \
# Rooms          1.000000  0.502835  0.313408  0.043256  0.621794  0.409352
# Price          0.502835  1.000000 -0.185238  0.222486  0.478325  0.227763
# Distance       0.313408 -0.185238  1.000000  0.192089  0.155879  0.289151
# Postcode       0.043256  0.222486  0.192089  1.000000  0.120908  0.021201
# Bathroom       0.621794  0.478325  0.155879  0.120908  1.000000  0.320393
# Car            0.409352  0.227763  0.289151  0.021201  0.320393  1.000000
# Landsize       0.117658  0.086564  0.081997  0.016569  0.087483  0.135648
# BuildingArea   0.610586  0.516983  0.172303  0.084872  0.550689  0.322483
# YearBuilt     -0.008117 -0.304918  0.332137 -0.012905  0.187791  0.133777
# Lattitude      0.026220 -0.269991  0.041429 -0.436413 -0.057158  0.025116
# Longtitude     0.103672  0.233028  0.246610  0.550958  0.121966  0.050523
# Propertycount -0.085272 -0.060558 -0.029821  0.047151 -0.059954 -0.036778
#
# ...

# %%
sns.heatmap(df.corr(), annot= True, cbar= False,linewidth=.1)

# %%
#sns.pairplot(df)

# %% [markdown]
# outliers

# %% [markdown]
# From the statistical information:

# %%
df.describe()
# Out:
#              Rooms         Price     Distance     Postcode     Bedroom2  \
# count  8887.000000  8.887000e+03  8887.000000  8887.000000  8887.000000
# mean      3.098909  1.092902e+06    11.199887  3111.662653     3.078204
# std       0.963786  6.793819e+05     6.813402   112.614268     0.966269
# min       1.000000  1.310000e+05     0.000000  3000.000000     0.000000
# 25%       2.000000  6.410000e+05     6.400000  3044.000000     2.000000
# 50%       3.000000  9.000000e+05    10.200000  3084.000000     3.000000
# 75%       4.000000  1.345000e+06    13.900000  3150.000000     4.000000
# max      12.000000  9.000000e+06    47.400000  3977.000000    12.000000
#
#           Bathroom          Car      Landsize  BuildingArea    YearBuilt  \
# count  8887.000000  8887.000000   8887.000000   8887.000000  8887.000000
# mean      1.646450     1.692247    523.480365    149.309477  1965.753348
# std       0.721611     0.975464   1061.324228     87.925580    37.040876
# ...

# %% [markdown]
# 9distribution of target variable

# %%
sns.boxplot(df['Price'])

# %%
sns.boxplot(df['Rooms'])

# %%
q1 = df['Rooms'].quantile(.25)

# %%
q3 = df['Rooms'].quantile(.75)

# %%
IQR = q3 - q1

# %%
IQR
# Out:
# 2.0

# %%
toprange = q3 + 1.5 * IQR
botrange = q1 - 1.5 * IQR
toprange
# Out:
# 7.0

# %%
botrange
# Out:
# -1.0

# %%
df = df.drop(df[df['Rooms'] > toprange].index)
df
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 2             Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 4             Abbotsford         5 Charles St      3    h  1465000.0     SP
# 6             Abbotsford          55a Park St      4    h  1600000.0     VB
# 11            Abbotsford         124 Yarra St      3    h  1876000.0      S
# 14            Abbotsford        98 Charles St      2    h  1636000.0      S
# 18            Abbotsford        10 Valiant St      2    h  1097000.0      S
# 24            Abbotsford      40 Nicholson St      3    h  1350000.0     VB
# 25            Abbotsford  123/56 Nicholson St      2    u   750000.0      S
# 30            Abbotsford        16 William St      2    h  1310000.0      S
# 32            Abbotsford          42 Henry St      3    h  1200000.0      S
# 35            Abbotsford          78 Yarra St      3    h  1176500.0      S
# ...

# %%
df = df.drop(df[df['Rooms'] < botrange].index)
df
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 2             Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 4             Abbotsford         5 Charles St      3    h  1465000.0     SP
# 6             Abbotsford          55a Park St      4    h  1600000.0     VB
# 11            Abbotsford         124 Yarra St      3    h  1876000.0      S
# 14            Abbotsford        98 Charles St      2    h  1636000.0      S
# 18            Abbotsford        10 Valiant St      2    h  1097000.0      S
# 24            Abbotsford      40 Nicholson St      3    h  1350000.0     VB
# 25            Abbotsford  123/56 Nicholson St      2    u   750000.0      S
# 30            Abbotsford        16 William St      2    h  1310000.0      S
# 32            Abbotsford          42 Henry St      3    h  1200000.0      S
# 35            Abbotsford          78 Yarra St      3    h  1176500.0      S
# ...

# %%
sns.boxplot(df['Rooms'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8881 entries, 2 to 34856
# Data columns (total 21 columns):
# Suburb           8881 non-null object
# Address          8881 non-null object
# Rooms            8881 non-null int64
# Type             8881 non-null object
# Price            8881 non-null float64
# Method           8881 non-null object
# SellerG          8881 non-null object
# Date             8881 non-null object
# Distance         8881 non-null float64
# Postcode         8881 non-null float64
# Bedroom2         8881 non-null float64
# Bathroom         8881 non-null float64
# Car              8881 non-null float64
# Landsize         8881 non-null float64
# BuildingArea     8881 non-null float64
# YearBuilt        8881 non-null float64
# CouncilArea      8881 non-null object
# Lattitude        8881 non-null float64
# Longtitude       8881 non-null float64
# Regionname       8881 non-null object
# Propertycount    8881 non-null float64
# ...

# %%
sns.boxplot(df['Distance'])

# %%
q1 = df['Distance'].quantile(.25)

# %%
q3 = df['Distance'].quantile(.75)

# %%
IQR = q3 - q1

# %%
toprange = q3 + 1.5 * IQR

# %%
botrange = q1 - 1.5 * IQR

# %%
toprange
# Out:
# 25.15

# %%
botrange
# Out:
# -4.85

# %%
df = df.drop(df[df['Distance'] > toprange].index)

# %%
df = df.drop(df[df['Distance'] < botrange].index)

# %%
df
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 2             Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 4             Abbotsford         5 Charles St      3    h  1465000.0     SP
# 6             Abbotsford          55a Park St      4    h  1600000.0     VB
# 11            Abbotsford         124 Yarra St      3    h  1876000.0      S
# 14            Abbotsford        98 Charles St      2    h  1636000.0      S
# 18            Abbotsford        10 Valiant St      2    h  1097000.0      S
# 24            Abbotsford      40 Nicholson St      3    h  1350000.0     VB
# 25            Abbotsford  123/56 Nicholson St      2    u   750000.0      S
# 30            Abbotsford        16 William St      2    h  1310000.0      S
# 32            Abbotsford          42 Henry St      3    h  1200000.0      S
# 35            Abbotsford          78 Yarra St      3    h  1176500.0      S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8476 entries, 2 to 34856
# Data columns (total 21 columns):
# Suburb           8476 non-null object
# Address          8476 non-null object
# Rooms            8476 non-null int64
# Type             8476 non-null object
# Price            8476 non-null float64
# Method           8476 non-null object
# SellerG          8476 non-null object
# Date             8476 non-null object
# Distance         8476 non-null float64
# Postcode         8476 non-null float64
# Bedroom2         8476 non-null float64
# Bathroom         8476 non-null float64
# Car              8476 non-null float64
# Landsize         8476 non-null float64
# BuildingArea     8476 non-null float64
# YearBuilt        8476 non-null float64
# CouncilArea      8476 non-null object
# Lattitude        8476 non-null float64
# Longtitude       8476 non-null float64
# Regionname       8476 non-null object
# Propertycount    8476 non-null float64
# ...

# %%
sns.boxplot(df['Distance'])

# %% [markdown]
# boxplot of categorical feature vs Price

# %%
sns.boxplot()

# %%
sns.boxplot(x ='Type', y ='Price', data = df)

# %%
sns.boxplot(x ='Method', y ='Price', data = df)

# %%
sns.boxplot(x ='Regionname', y ='Price', data = df)

# %%
df['Regionname']
# Out:
# 2             Northern Metropolitan
# 4             Northern Metropolitan
# 6             Northern Metropolitan
# 11            Northern Metropolitan
# 14            Northern Metropolitan
# 18            Northern Metropolitan
# 24            Northern Metropolitan
# 25            Northern Metropolitan
# 30            Northern Metropolitan
# 32            Northern Metropolitan
# 35            Northern Metropolitan
# 37            Northern Metropolitan
# 38            Northern Metropolitan
# 42            Northern Metropolitan
# 43            Northern Metropolitan
# 44            Northern Metropolitan
# 49            Northern Metropolitan
# 51            Northern Metropolitan
# 56            Northern Metropolitan
# 57            Northern Metropolitan
# 58            Northern Metropolitan
# 59            Northern Metropolitan
# 61            Northern Metropolitan
# 63            Northern Metropolitan
# 66             Western Metropolitan
# 67             Western Metropolitan
# ...

# %%
df['Regionname'] = df['Regionname'].map({'Northern Metropolitan':'N Metro','Western Metropolitan': 'W Metro',
                                         'Eastern metropolitan':'E Metro','South-Eastern Metropolitan': 'S-E Metropolitan'})

# %%
sns.boxplot(x ='Regionname', y ='Price', data = df)

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bathroom', 'Car', 'Landsize',
#        'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude',
#        'Regionname', 'Propertycount'],
#       dtype='object')

# %%
X = df[['Rooms','Distance','Bathroom', 'Car', 'Landsize',
       'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude',
       'Propertycount']]

# %%
Y = df['Price']

# %%
 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.intercept_
# Out:
# -223063888.435

# %%
lm.coef_
# Out:
# array([  2.01601944e+05,  -4.49297836e+04,   1.95632105e+05,
#          6.23191695e+04,   2.12918163e+01,   1.85883672e+03,
#         -4.25250232e+03,  -1.61330023e+06,   1.17715770e+06,
#         -3.75885139e-01])

# %%
pd.DataFrame(lm.coef_,X.columns, columns =['coeff'])
# Out:
#                       coeff
# Rooms          2.016019e+05
# Distance      -4.492978e+04
# Bathroom       1.956321e+05
# Car            6.231917e+04
# Landsize       2.129182e+01
# BuildingArea   1.858837e+03
# YearBuilt     -4.252502e+03
# Lattitude     -1.613300e+06
# Longtitude     1.177158e+06
# Propertycount -3.758851e-01

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([ 1315023.25724593,  1453365.88810807,   869650.72194207, ...,
#          487815.89540941,   951916.03453603,   534698.05016276])

# %%
sns.regplot(Y_test, predictions)

# %%
sns.distplot((Y_test-predictions))

# %%
lm.score(X,Y)
# Out:
# 0.60778356931177147

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(Y_test,predictions)
# Out:
# 274592.64535696647

# %%
metrics.mean_squared_error(Y_test,predictions)
# Out:
# 160918790836.91888

# %%
np.sqrt(metrics.mean_squared_error(Y_test,predictions))
# Out:
# 401146.84448081965

# %%
print('R^2 =',metrics.explained_variance_score(Y_test,predictions))
# Out:
# R^2 = 0.627610018617

# %%
import matplotlib.pyplot as plt
plt.scatter(Y_test, predictions)
